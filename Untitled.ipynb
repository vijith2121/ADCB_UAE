# %%
import pandas as pd

# %%
df = pd.read_csv('ADCB_UAE.csv', dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Designation_Occupation  10 non-null     object
#  1   Email_ID                10 non-null     object
#  2   Emirates_id             10 non-null     object
#  3   Home_Country_Number     8 non-null      object
#  4   Mobile_Number           10 non-null     object
#  5   Office_Numbers          10 non-null     object
#  6   Reference_name_mobile   5 non-null      object
#  7   Residence_number        10 non-null     object
#  8   address                 10 non-null     object
#  9   cid_no                  10 non-null     object
#  10  date_of_birth           10 non-null     object
#  11  employer_name           10 non-null     object
#  12  gender                  10 non-null     object
#  13  name                    10 non-null     object
# ...

# %%
df
# Out:
#      Designation_Occupation                      Email_ID      Emirates_id  \
# 0                 / Manager   ibrar.hussain0212@gmail.com  784198472731532
# 1    / STRUCTURAL DRAFTSMAN            RIYAS349@GMAIL.COM  784198891728242
# 2          / SENIOR OFFICER        syedbaqui.11@gmail.com  784197906382748
# 3            / TRUCK DRIVER    balwinder1956615@gmail.com  784195696859800
# 4      / COMMERCIAL MANAGER           ha5himz@hotmail.com  784198270303914
# 5   / SR COMMERCIAL MANAGER  PRATHEESH.AYYAPPAN@GMAIL.COM  784197231796182
# 6           / SR TECHNICAIN       RICHARDPARGAS@YAHOO.COM  784197274971080
# 7           / SALES MANAGER     ANILPONNAPPAN@OUTLOOK.COM  784197619432525
# 8  / SR BUSINESS CONSULTANT         AZHARBUX187@GMAIL.COM  784198237438605
# 9      / ASSOCIATE ENGINEER           DEEPAKKJ3@GMAIL.COM  784198985474612
#
#   Home_Country_Number Mobile_Number                 Office_Numbers  \
# 0      00923333640756  971504322662      97172446533 / 97172446533
# ...

# %%
df.tail()
# Out:
#      Designation_Occupation                      Email_ID      Emirates_id  \
# 5   / SR COMMERCIAL MANAGER  PRATHEESH.AYYAPPAN@GMAIL.COM  784197231796182
# 6           / SR TECHNICAIN       RICHARDPARGAS@YAHOO.COM  784197274971080
# 7           / SALES MANAGER     ANILPONNAPPAN@OUTLOOK.COM  784197619432525
# 8  / SR BUSINESS CONSULTANT         AZHARBUX187@GMAIL.COM  784198237438605
# 9      / ASSOCIATE ENGINEER           DEEPAKKJ3@GMAIL.COM  784198985474612
#
#   Home_Country_Number Mobile_Number             Office_Numbers  \
# 5      00914842608877  971508501210  97142215267 / 97146089458
# 6       0063324569357  971503560129  97143274787 / 97143274787
# 7      00919400343794  971503572751    97142596123 / 043965661
# 8         00166729040  971504615882  97143914391 / 97143616738
# 9      00919654352098  971563106726  97126182731 / 97142277444
#
#      Reference_name_mobile Residence_number  \
# 5  SREEJITH / 971505361138    97146089458 /
# ...

# %%
df.to_dict()
# Out:
# {'Designation_Occupation': {0: '/ Manager',
#   1: '/ STRUCTURAL DRAFTSMAN',
#   2: '/ SENIOR OFFICER',
#   3: '/ TRUCK DRIVER',
#   4: '/ COMMERCIAL MANAGER',
#   5: '/ SR COMMERCIAL MANAGER',
#   6: '/ SR TECHNICAIN',
#   7: '/ SALES MANAGER',
#   8: '/ SR BUSINESS CONSULTANT',
#   9: '/ ASSOCIATE ENGINEER'},
#  'Email_ID': {0: 'ibrar.hussain0212@gmail.com',
#   1: 'RIYAS349@GMAIL.COM',
#   2: 'syedbaqui.11@gmail.com',
#   3: 'balwinder1956615@gmail.com',
#   4: 'ha5himz@hotmail.com',
#   5: 'PRATHEESH.AYYAPPAN@GMAIL.COM',
#   6: 'RICHARDPARGAS@YAHOO.COM',
#   7: 'ANILPONNAPPAN@OUTLOOK.COM',
#   8: 'AZHARBUX187@GMAIL.COM',
#   9: 'DEEPAKKJ3@GMAIL.COM'},
#  'Emirates_id': {0: '784198472731532',
#   1: '784198891728242',
#   2: '784197906382748',
#   3: '784195696859800',
#   4: '784198270303914',
#   5: '784197231796182',
#   6: '784197274971080',
#   7: '784197619432525',
#   8: '784198237438605',
#   9: '784198985474612'},
#  'Home_Country_Number': {0: '00923333640756',
# ...
